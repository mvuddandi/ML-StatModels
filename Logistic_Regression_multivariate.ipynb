# %% [markdown]
# <a href="https://colab.research.google.com/github/mvuddandi/ML-StatModels/blob/main/Logistic_Regression_multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mvuddandi/ML-StatModels.git
# Out:
# Cloning into 'ML-StatModels'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 72 (delta 32), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (72/72), 669.39 KiB | 8.06 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# %cd ML-StatModels/
# Out:
# /content/ML-StatModels

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Iris.csv")
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df_modified = df.drop(['Id'], axis='columns')

# %%
df_modified
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_modified.Species = le.fit_transform(df_modified['Species'])

# %%
df_modified.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0
# 5            5.4           3.9            1.7           0.4        0
# 6            4.6           3.4            1.4           0.3        0
# 7            5.0           3.4            1.5           0.2        0
# 8            4.4           2.9            1.4           0.2        0
# 9            4.9           3.1            1.5           0.1        0

# %%
from sklearn.model_selection import train_test_split

# %%
df_modified.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
X_Train, X_Test, y_Train, y_Test = train_test_split(df_modified[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']], df_modified.Species,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

# %%
model.fit(X_Train,y_Train)
# Out:
# LogisticRegression()

# %%
model.score(X_Train,y_Train)
# Out:
# 0.975

# %%
model.predict([[6.8,3,5.5,2.1]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([2])
