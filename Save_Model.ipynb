# %% [markdown]
# <a href="https://colab.research.google.com/github/mvuddandi/ML-StatModels/blob/main/Save_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/mvuddandi/ML-StatModels.git
# Out:
# Cloning into 'ML-StatModels'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 33 (delta 12), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 63.19 KiB | 3.16 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# %cd ML-StatModels/
# Out:
# /content/ML-StatModels

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv("prices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
model = linear_model.LinearRegression()

# %%
model.fit (df[['area']], df['price'])
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [135.78767123]
# 180616.43835616432

# %%
import pickle
with open('model_pickle','wb') as f:
  pickle.dump(model,f)

# %%
with open('model_pickle','rb') as f:
 lp =  pickle.load(f)

# %%
lp.predict([[2700]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([547243.15068493])

# %%
# !pip install joblib
import joblib

# %%
joblib.dump(model, 'model_joblib')
# Out:
# ['model_joblib']

# %%
lpjl = joblib.load('model_joblib')

# %%
lpjl.predict([[2700]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([547243.15068493])
